# %%
#pip install autofeat

# %%
import os
import sys
import warnings
import sklearn
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston, load_diabetes
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from autofeat import AutoFeatRegressor
from boruta import BorutaPy

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# ignore all future warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
np.seterr(divide = 'ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
#regr adatbeolvasó fv.
def load_regression_dataset(name):
    units = {}
    if name == "boston":
        X, y = load_boston(True)
    elif name == "diabetes":
        X, y = load_diabetes(True)
    else:
        raise RuntimeError("Unknown dataset %r" % name)
    return np.array(X, dtype=float), np.array(y, dtype=float), units

# %%
#módosított modell tesztelő fv.
def test_model(X, y, model, param_grid):
    # load data
    #X, y, _ = load_regression_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    
    if model.__class__.__name__ == "SVR":
        sscaler = StandardScaler()
        X_train = sscaler.fit_transform(X_train)
        X_test = sscaler.transform(X_test)
        
    # train model on train split incl cross-validation for parameter selection
    gsmodel = GridSearchCV(model, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test)))
    return gsmodel.best_estimator_

# %%
#módosított autofeat modell tesztelő fv.
def test_autofeat(X, y, units, feateng_steps=2):
    # load data
    #X, y, units = load_regression_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    # run autofeat
    afreg = AutoFeatRegressor(verbose=1, feateng_steps=feateng_steps, units=units)
    # fit autofeat on less data, otherwise ridge reg model with xval will overfit on new features
    X_train_tr = afreg.fit_transform(X_train, y_train)
    X_test_tr = afreg.transform(X_test)
    print("autofeat new features:", len(afreg.new_feat_cols_))
    print("autofeat MSE on training data:", mean_squared_error(y_train, afreg.predict(X_train_tr)))
    print("autofeat MSE on test data:", mean_squared_error(y_test, afreg.predict(X_test_tr)))
    print("autofeat R^2 on training data:", r2_score(y_train, afreg.predict(X_train_tr)))
    print("autofeat R^2 on test data:", r2_score(y_test, afreg.predict(X_test_tr)))
    
    
    # train rreg on transformed train split incl cross-validation for parameter selection
    print("# Ridge Regression")
    rreg = Ridge()
    param_grid = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000.]}
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        gsmodel = GridSearchCV(rreg, param_grid, scoring='neg_mean_squared_error', cv=5)
        gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))
    
    
    print("# Random Forest")
    rforest = RandomForestRegressor(n_estimators=100, random_state=13)
    param_grid = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
    gsmodel = GridSearchCV(rforest, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))
    
    
    print("# SVR")
    svr = SVR(gamma="scale")
    param_grid = {"C": [1., 10., 25., 50., 100., 250.]}
    sscaler = StandardScaler()
    X_train_tr = sscaler.fit_transform(X_train_tr)
    X_test_tr = sscaler.transform(X_test_tr)
    gsmodel = GridSearchCV(svr, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))

# %%
#adatok beolvasása
X, y, units = load_regression_dataset("diabetes")
#új változók generálása autofeattel
afreg = AutoFeatRegressor(verbose=1, feateng_steps=2, units=units)
#és a legjobbak kiválasztása
X_af = afreg.fit_transform(X, y)
X_af.shape
# Out:
# [AutoFeat] The 2 step feature engineering process could generate up to 2485 features.
# [AutoFeat] With 442 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 45 transformed features from 10 original features - done.
# [feateng] Step 2: first combination of features
# [feateng] Generated 1337 feature combinations from 1485 original feature tuples - done.
# [feateng] Generated altogether 1495 new features in 2 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 918 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 32 features after 5 feature selection runs
# [featsel] 31 features after correlation filtering
# [featsel] 7 features after noise filtering
# [AutoFeat] Computing 7 new features.
# [AutoFeat]     7/    7 new features ...done.
# [AutoFeat] Final dataframe with 17 feature columns (7 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# -414.26634051585995
# 860791.862415 * x000**3*x001
# -4098.390574 * x006*Abs(x009)
# 2982.821346 * x002*x003
# 280.694031 * exp(x002)*exp(x008)
# 280.203069 * exp(x002)*exp(x003)
# 12.090366 * Abs(x008)/x008
# 0.678971 * x001/x007
# [AutoFeat] Final score: 0.5451
# (442, 17)

# %%
randforreg = RandomForestRegressor(random_state=13)
randforreg.fit(X_af, y)
# define Boruta feature selection method
feat_selector = BorutaPy(randforreg, n_estimators='auto', verbose=2, random_state=11)
# find all relevant features
feat_selector.fit(X_af.iloc[:,:].values, y)
# call transform() on X to filter it down to selected features
XS_af = feat_selector.transform(X_af.iloc[:,:].values)
XS_af.shape
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	2
# Tentative: 	6
# Rejected: 	9
# Iteration: 	9 / 100
# Confirmed: 	2
# Tentative: 	6
# Rejected: 	9
# Iteration: 	10 / 100
# Confirmed: 	2
# Tentative: 	6
# Rejected: 	9
# Iteration: 	11 / 100
# Confirmed: 	2
# Tentative: 	6
# Rejected: 	9
# Iteration: 	12 / 100
# Confirmed: 	2
# Tentative: 	5
# Rejected: 	10
# Iteration: 	13 / 100
# Confirmed: 	2
# Tentative: 	5
# Rejected: 	10
# Iteration: 	14 / 100
# Confirmed: 	2
# Tentative: 	5
# Rejected: 	10
# Iteration: 	15 / 100
# Confirmed: 	2
# Tentative: 	5
# Rejected: 	10
# Iteration: 	16 / 100
# Confirmed: 	2
# Tentative: 	5
# Rejected: 	10
# Iteration: 	17 / 100
# Confirmed: 	2
# Tentative: 	5
# Rejected: 	10
# Iteration: 	18 / 100
# Confirmed: 	2
# Tentative: 	5
# Rejected: 	10
# Iteration: 	19 / 100
# Confirmed: 	2
# Tentative: 	5
# Rejected: 	10
# Iteration: 	20 / 100
# Confirmed: 	2
# Tentative: 	5
# Rejected: 	10
# Iteration: 	21 / 100
# Confirmed: 	2
# Tentative: 	5
# Rejected: 	10
# Iteration: 	22 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	23 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	24 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	25 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	26 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	27 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	28 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	29 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	30 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	31 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	32 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	33 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	34 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	35 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	36 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	37 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	38 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	39 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	40 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	41 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	42 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	43 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	44 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	45 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	46 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	47 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	48 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	49 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	50 / 100
# Confirmed: 	3
# Tentative: 	3
# Rejected: 	11
# Iteration: 	51 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	52 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	53 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	54 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	55 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	56 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	57 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	58 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	59 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	60 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	61 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	62 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	63 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	64 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	65 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	66 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	67 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	68 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	69 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	70 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	71 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	72 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	73 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	74 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	75 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	76 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	77 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	78 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	79 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	80 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	81 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	82 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	83 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	84 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	85 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	86 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	87 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	88 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	89 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	90 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	91 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	92 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	93 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	94 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	95 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	96 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	97 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	98 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
# Iteration: 	99 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	11
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	11
# (442, 4)

# %% [markdown]
# ## Adathalmaz tesztelése

# %%
dsname='diabetes'

# %%
#Ridge regresszió
print("####", dsname)
warnings.simplefilter("ignore")
rreg = Ridge()
params = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000., 25000., 50000., 100000.]}
rreg = test_model(XS_af, y, rreg, params)
# Out:
# #### diabetes
# best params: {'alpha': 0.0001}
# best score: -3039.118259953061
# MSE on training data: 2897.935541084834
# MSE on test data: 3186.220241683717
# R^2 on training data: 0.5282356903183567
# R^2 on test data: 0.3698398082373112

# %%
#SVR regresszió
print("####", dsname)
svr = SVR(gamma="scale")
params = {"C": [1., 10., 25., 50., 100., 250.]}
svr = test_model(XS_af, y, svr, params)
# Out:
# #### diabetes
# best params: {'C': 25.0}
# best score: -3203.2151103931456
# MSE on training data: 2759.946445356669
# MSE on test data: 3517.017277098798
# R^2 on training data: 0.5506993819936459
# R^2 on test data: 0.3044158552586117

# %%
#random forest regresszió
print("####", dsname)
rforest = RandomForestRegressor(n_estimators=100, random_state=13)
params = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
rforest = test_model(XS_af, y, rforest, params)
# Out:
# #### diabetes
# best params: {'min_samples_leaf': 0.05}
# best score: -3100.9431380722945
# MSE on training data: 2424.5940607209045
# MSE on test data: 3534.994671345606
# R^2 on training data: 0.6052924824939281
# R^2 on test data: 0.3008603451724742

# %%
#autofeat regresszió 1 steppel
print("####", dsname)
test_autofeat(XS_af, y, units, feateng_steps=1)
# Out:
# #### diabetes
# [AutoFeat] The 1 step feature engineering process could generate up to 28 features.
# [AutoFeat] With 353 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 20 transformed features from 4 original features - done.
# [feateng] Generated altogether 22 new features in 1 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 6 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 4 features after 5 feature selection runs
# [featsel] 4 features after correlation filtering
# [featsel] 4 features after noise filtering
# [AutoFeat] Final dataframe with 4 feature columns (0 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# -484.2132587654006
# -5042.893404 * x002
# 2751.474737 * x003
# 418.761444 * x000
# 213.365008 * x001
# [AutoFeat] Final score: 0.5283
# autofeat new features: 0
# autofeat MSE on training data: 2897.363711881356
# autofeat MSE on test data: 3191.205064469304
# autofeat R^2 on training data: 0.5283287802458619
# autofeat R^2 on test data: 0.36885392633204517
# # Ridge Regression
# best params: {'alpha': 0.0001}
# best score: -3039.118259953061
# MSE on training data: 2897.935541084834
# MSE on test data: 3186.220241683717
# R^2 on training data: 0.5282356903183567
# R^2 on test data: 0.3698398082373112
# # Random Forest
# best params: {'min_samples_leaf': 0.05}
# best score: -3100.9431380722945
# MSE on training data: 2424.5940607209045
# MSE on test data: 3534.994671345606
# R^2 on training data: 0.6052924824939281
# R^2 on test data: 0.3008603451724742
# # SVR
# best params: {'C': 25.0}
# best score: -3203.2151103931456
# MSE on training data: 2759.946445356669
# MSE on test data: 3517.017277098798
# R^2 on training data: 0.5506993819936459
# R^2 on test data: 0.3044158552586117

# %%
#autofeat regresszió 2 steppel
print("####", dsname)
test_autofeat(XS_af, y, units, feateng_steps=2)
# Out:
# #### diabetes
# [AutoFeat] The 2 step feature engineering process could generate up to 406 features.
# [AutoFeat] With 353 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 20 transformed features from 4 original features - done.
# [feateng] Step 2: first combination of features
# [feateng] Generated 246 feature combinations from 276 original feature tuples - done.
# [feateng] Generated altogether 285 new features in 2 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 55 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 9 features after 5 feature selection runs
# [featsel] 9 features after correlation filtering
# [featsel] 4 features after noise filtering
# [AutoFeat] Computing 1 new features.
# [AutoFeat]     1/    1 new features ...done.
# [AutoFeat] Final dataframe with 5 feature columns (1 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# -2022.4780783559706
# -5144.118265 * x002
# 571.889389 * exp(x001)/x001
# 411.768339 * x000
# 201.467781 * x001
# [AutoFeat] Final score: 0.5277
# [AutoFeat] Computing 1 new features.
# [AutoFeat]     1/    1 new features ...done.
# autofeat new features: 1
# autofeat MSE on training data: 2901.0253624514476
# autofeat MSE on test data: 3195.6000672769387
# autofeat R^2 on training data: 0.5277326882938485
# autofeat R^2 on test data: 0.36798469708799486
# # Ridge Regression
# best params: {'alpha': 0.0001}
# best score: -3042.2391225789083
# MSE on training data: 2896.8431575193754
# MSE on test data: 3183.3910837281205
# R^2 on training data: 0.5284135229759019
# R^2 on test data: 0.37039934982094125
# # Random Forest
# best params: {'min_samples_leaf': 0.05}
# best score: -3118.5716107902035
# MSE on training data: 2422.37761972024
# MSE on test data: 3536.634177041871
# R^2 on training data: 0.6056533041008287
# R^2 on test data: 0.30053608911181695
# # SVR
# best params: {'C': 25.0}
# best score: -3178.5992186139774
# MSE on training data: 2742.703679517197
# MSE on test data: 3594.9776576644017
# R^2 on training data: 0.5535063876733566
# R^2 on test data: 0.28899710682295665

# %%
#autofeat regresszió 3 steppel
print("####", dsname)
test_autofeat(XS_af, y, units, feateng_steps=3)
# Out:
# #### diabetes
# [AutoFeat] The 3 step feature engineering process could generate up to 9478 features.
# [AutoFeat] With 353 data points this new feature matrix would use about 0.01 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 20 transformed features from 4 original features - done.
# [feateng] Step 2: first combination of features
# [feateng] Generated 1062 feature combinations from 276 original feature tuples - done.
# [feateng] Step 3: transformation of new features
# [feateng] Generated 4824 transformed features from 1062 original features - done.
# [feateng] Generated altogether 6229 new features in 3 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 1522 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 18 features after 5 feature selection runs
# [featsel] 14 features after correlation filtering
# [featsel] 9 features after noise filtering
# [AutoFeat] Computing 6 new features.
# [AutoFeat]     6/    6 new features ...done.
# [AutoFeat] Final dataframe with 10 feature columns (6 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# -445.5334377679545
# -3508.771063 * x002
# 422.570246 * x000
# 161.815618 * x001
# 134.524128 * x001**2*Abs(log(x001))
# -83.837903 * x002/log(x000)
# 81.406633 * sqrt(-x002 + Abs(x002))
# -0.030300 * 1/(x002**2 - log(x001))
# [AutoFeat] Final score: 0.5653
# [AutoFeat] Computing 6 new features.
# [AutoFeat]     6/    6 new features ...done.
# autofeat new features: 6
# autofeat MSE on training data: 2669.9680236598206
# autofeat MSE on test data: 15948.467026633176
# autofeat R^2 on training data: 0.5653472605942054
# autofeat R^2 on test data: -2.1542355133972912
# # Ridge Regression
# best params: {'alpha': 0.1}
# best score: -2872.342012989999
# MSE on training data: 2697.6657953814342
# MSE on test data: 25527.561957825295
# R^2 on training data: 0.5608382506556768
# R^2 on test data: -4.048757498972019
# # Random Forest
# best params: {'min_samples_leaf': 0.05}
# best score: -3159.9093006768717
# MSE on training data: 2367.012083859417
# MSE on test data: 3570.286154816668
# R^2 on training data: 0.6146664389463876
# R^2 on test data: 0.2938805112925782
# # SVR
# best params: {'C': 25.0}
# best score: -3222.8032019706447
# MSE on training data: 2645.6489492100322
# MSE on test data: 3778.893968716228
# R^2 on training data: 0.5693062414642927
# R^2 on test data: 0.25262274188594247
