# %%
#pip install autofeat

# %%
import os
import sys
import warnings
import sklearn
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston, load_diabetes
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from autofeat import AutoFeatRegressor
from boruta import BorutaPy

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# ignore all future warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
np.seterr(divide = 'ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
#regr adatbeolvasó fv.
def load_regression_dataset(name):
    units = {}
    if name == "boston":
        X, y = load_boston(True)
    elif name == "diabetes":
        X, y = load_diabetes(True)
    else:
        raise RuntimeError("Unknown dataset %r" % name)
    return np.array(X, dtype=float), np.array(y, dtype=float), units

# %%
#módosított modell tesztelő fv.
def test_model(X, y, model, param_grid):
    # load data
    #X, y, _ = load_regression_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    
    if model.__class__.__name__ == "SVR":
        sscaler = StandardScaler()
        X_train = sscaler.fit_transform(X_train)
        X_test = sscaler.transform(X_test)
        
    # train model on train split incl cross-validation for parameter selection
    gsmodel = GridSearchCV(model, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test)))
    return gsmodel.best_estimator_

# %%
#módosított autofeat modell tesztelő fv.
def test_autofeat(X, y, units, feateng_steps=2):
    # load data
    #X, y, units = load_regression_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    # run autofeat
    afreg = AutoFeatRegressor(verbose=1, feateng_steps=feateng_steps, units=units)
    # fit autofeat on less data, otherwise ridge reg model with xval will overfit on new features
    X_train_tr = afreg.fit_transform(X_train, y_train)
    X_test_tr = afreg.transform(X_test)
    print("autofeat new features:", len(afreg.new_feat_cols_))
    print("autofeat MSE on training data:", mean_squared_error(y_train, afreg.predict(X_train_tr)))
    print("autofeat MSE on test data:", mean_squared_error(y_test, afreg.predict(X_test_tr)))
    print("autofeat R^2 on training data:", r2_score(y_train, afreg.predict(X_train_tr)))
    print("autofeat R^2 on test data:", r2_score(y_test, afreg.predict(X_test_tr)))
    
    
    # train rreg on transformed train split incl cross-validation for parameter selection
    print("# Ridge Regression")
    rreg = Ridge()
    param_grid = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000.]}
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        gsmodel = GridSearchCV(rreg, param_grid, scoring='neg_mean_squared_error', cv=5)
        gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))
    
    
    print("# Random Forest")
    rforest = RandomForestRegressor(n_estimators=100, random_state=13)
    param_grid = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
    gsmodel = GridSearchCV(rforest, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))
    
    
    print("# SVR")
    svr = SVR(gamma="scale")
    param_grid = {"C": [1., 10., 25., 50., 100., 250.]}
    sscaler = StandardScaler()
    X_train_tr = sscaler.fit_transform(X_train_tr)
    X_test_tr = sscaler.transform(X_test_tr)
    gsmodel = GridSearchCV(svr, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))

# %%
#adatok beolvasása
X, y, units = load_regression_dataset("boston")
#új változók generálása autofeattel
afreg = AutoFeatRegressor(verbose=1, feateng_steps=1, units=units)
#és a legjobbak kiválasztása
X_af = afreg.fit_transform(X, y)
X_af.shape
# Out:
# [AutoFeat] The 1 step feature engineering process could generate up to 91 features.
# [AutoFeat] With 506 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 60 transformed features from 13 original features - done.
# [feateng] Generated altogether 61 new features in 1 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 22 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 23 features after 5 feature selection runs
# [featsel] 21 features after correlation filtering
# [featsel] 9 features after noise filtering
# [AutoFeat] Computing 4 new features.
# [AutoFeat]     4/    4 new features ...done.
# [AutoFeat] Final dataframe with 17 feature columns (4 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 26.746281945465803
# 41.962814 * 1/x012
# 4.777565 * 1/x002
# 2.181179 * x003
# -0.555992 * x010
# -0.291267 * x012
# -0.090812 * x000
# 0.007442 * x011
# -0.006071 * x007**3
# 0.003421 * exp(x005)
# [AutoFeat] Final score: 0.7933
# (506, 17)

# %%
randforreg = RandomForestRegressor(random_state=13)
randforreg.fit(X_af, y)
# define Boruta feature selection method
feat_selector = BorutaPy(randforreg, n_estimators='auto', verbose=2, random_state=11)
# find all relevant features
feat_selector.fit(X_af.iloc[:,:].values, y)
# call transform() on X to filter it down to selected features
XS_af = feat_selector.transform(X_af.iloc[:,:].values)
XS_af.shape
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	17
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	5
# Iteration: 	9 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	5
# Iteration: 	10 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	5
# Iteration: 	11 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	5
# Iteration: 	12 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	5
# Iteration: 	13 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	5
# Iteration: 	14 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	5
# Iteration: 	15 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	5
# Iteration: 	16 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	5
# Iteration: 	17 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	5
# Iteration: 	18 / 100
# Confirmed: 	10
# Tentative: 	2
# Rejected: 	5
# Iteration: 	19 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	20 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	21 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	22 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	23 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	24 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	25 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	26 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	27 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	28 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	29 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	30 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	31 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	32 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	33 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	34 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	35 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	36 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	37 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	38 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	39 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	40 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	41 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	42 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	43 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	44 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	45 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	46 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	47 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	48 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	49 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	50 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	51 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	52 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	53 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	54 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	55 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	56 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	57 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	58 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	59 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	60 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	61 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	62 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	63 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	64 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	65 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	66 / 100
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	5
# Iteration: 	67 / 100
# Confirmed: 	12
# Tentative: 	0
# Rejected: 	5
#
#
# BorutaPy finished running.
#
# Iteration: 	68 / 100
# Confirmed: 	12
# Tentative: 	0
# Rejected: 	5
# (506, 12)

# %% [markdown]
# ## Adathalmaz tesztelése

# %%
dsname='boston'

# %%
#Ridge regresszió
print("####", dsname)
rreg = Ridge()
params = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000., 25000., 50000., 100000.]}
rreg = test_model(XS_af, y, rreg, params)
# Out:
# #### boston
# best params: {'alpha': 1e-05}
# best score: -19.361262406264004
# MSE on training data: 17.080593276242897
# MSE on test data: 15.367197777956761
# R^2 on training data: 0.7990644514523546
# R^2 on test data: 0.8119307049085114

# %%
#SVR regresszió
print("####", dsname)
svr = SVR(gamma="scale")
params = {"C": [1., 10., 25., 50., 100., 250.]}
svr = test_model(XS_af, y, svr, params)
# Out:
# #### boston
# best params: {'C': 25.0}
# best score: -12.604237051735236
# MSE on training data: 5.963702688738193
# MSE on test data: 8.43732059001162
# R^2 on training data: 0.9298431938659064
# R^2 on test data: 0.8967410351091758

# %%
#random forest regresszió
print("####", dsname)
rforest = RandomForestRegressor(n_estimators=100, random_state=13)
params = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
rforest = test_model(XS_af, y, rforest, params)
# Out:
# #### boston
# best params: {'min_samples_leaf': 0.0001}
# best score: -10.480986581820982
# MSE on training data: 1.4434100148514855
# MSE on test data: 11.259093401960794
# R^2 on training data: 0.9830197711272273
# R^2 on test data: 0.8622071642421758

# %%
#autofeat regresszió 1 steppel
print("####", dsname)
test_autofeat(XS_af, y, units, feateng_steps=1)
# Out:
# #### boston
# [AutoFeat] The 1 step feature engineering process could generate up to 84 features.
# [AutoFeat] With 404 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 63 transformed features from 12 original features - done.
# [feateng] Generated altogether 63 new features in 1 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 29 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 14 features after 5 feature selection runs
# [featsel] 14 features after correlation filtering
# [featsel] 12 features after noise filtering
# [AutoFeat] Computing 4 new features.
# [AutoFeat]     4/    4 new features ...done.
# [AutoFeat] Final dataframe with 16 feature columns (4 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 46.0022067442621
# 25.767287 * x009
# 24.087530 * 1/x011
# -22.294145 * x001
# -16.380544 * 1/x003
# 0.625102 * log(x000)
# -0.563116 * x004
# -0.467312 * x008
# -0.458922 * x006
# -0.209239 * x000
# 0.006812 * x010
# -0.005611 * x005
# [AutoFeat] Final score: 0.8473
# [AutoFeat] Computing 4 new features.
# [AutoFeat]     4/    4 new features ...done.
# autofeat new features: 4
# autofeat MSE on training data: 12.984049763055872
# autofeat MSE on test data: 17.393202772797192
# autofeat R^2 on training data: 0.8472560572507566
# autofeat R^2 on test data: 0.7871357268821313
# # Ridge Regression
# best params: {'alpha': 0.1}
# best score: -15.737466133457104
# MSE on training data: 12.713014052575067
# MSE on test data: 15.69401782476784
# R^2 on training data: 0.8504445126094595
# R^2 on test data: 0.8079309635949913
# # Random Forest
# best params: {'min_samples_leaf': 0.0001}
# best score: -10.302454492407401
# MSE on training data: 1.412402537128713
# MSE on test data: 11.42845735294118
# R^2 on training data: 0.9833845420953393
# R^2 on test data: 0.8601344272776994
# # SVR
# best params: {'C': 25.0}
# best score: -10.597204234911564
# MSE on training data: 3.1883461298204754
# MSE on test data: 8.585978511433456
# R^2 on training data: 0.9624923989352108
# R^2 on test data: 0.8949217059838831

# %%
#autofeat regresszió 2 steppel
warnings.simplefilter("ignore")
print("####", dsname)
test_autofeat(XS_af, y, units, feateng_steps=2)
# Out:
# #### boston
# [AutoFeat] The 2 step feature engineering process could generate up to 3570 features.
# [AutoFeat] With 404 data points this new feature matrix would use about 0.01 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 63 transformed features from 12 original features - done.
# [feateng] Step 2: first combination of features
# [feateng] Generated 2718 feature combinations from 2775 original feature tuples - done.
# [feateng] Generated altogether 2791 new features in 2 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 1262 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 36 features after 5 feature selection runs
# [featsel] 23 features after correlation filtering
# [featsel] 14 features after noise filtering
# [AutoFeat] Computing 13 new features.
# [AutoFeat]    13/   13 new features ...done.
# [AutoFeat] Final dataframe with 25 feature columns (13 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 8.675259099606436
# 146.067820 * x009/x011
# 60.368544 * sqrt(x010)/x005
# -14.798375 * log(x001)/x004
# 1.982399 * x002**2/x006
# -0.073313 * x000
# -0.071830 * x001**2/x009
# 0.057154 * x005/x008
# -0.015487 * x006*log(x008)
# 0.000023 * x002**3*x007
# [AutoFeat] Final score: 0.8908
# [AutoFeat] Computing 13 new features.
# [AutoFeat]    13/   13 new features ...done.
# autofeat new features: 13
# autofeat MSE on training data: 9.286455427859764
# autofeat MSE on test data: 12.040320679902571
# autofeat R^2 on training data: 0.8907544377831642
# autofeat R^2 on test data: 0.8526462237511575
# # Ridge Regression
# best params: {'alpha': 0.01}
# best score: -11.715599096507058
# MSE on training data: 8.830533582674452
# MSE on test data: 11.223588702890677
# R^2 on training data: 0.896117887668982
# R^2 on test data: 0.8626416835229864
# # Random Forest
# best params: {'min_samples_leaf': 0.0001}
# best score: -10.447521012283948
# MSE on training data: 1.305737247524751
# MSE on test data: 10.249993588235295
# R^2 on training data: 0.9846393491228783
# R^2 on test data: 0.8745568908082342
# # SVR
# best params: {'C': 25.0}
# best score: -11.753174538473159
# MSE on training data: 2.951502982089509
# MSE on test data: 7.896333303774038
# R^2 on training data: 0.9652786140882444
# R^2 on test data: 0.9033618321501369

# %%
#sokáig futna
#autofeat regresszió 3 steppel
#print("####", dsname)
#test_autofeat(XS_af, y, units, feateng_steps=3)
