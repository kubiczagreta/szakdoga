# %%
#pip install autofeat

# %%
import os
import sys
import warnings
import sklearn
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston, load_diabetes
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from autofeat import AutoFeatRegressor
from boruta import BorutaPy

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# ignore all future warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
np.seterr(divide = 'ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
#regr adatbeolvasó fv.
def load_regression_dataset(name):
    units = {}
    if name == "boston":
        X, y = load_boston(True)
    elif name == "diabetes":
        X, y = load_diabetes(True)
    else:
        raise RuntimeError("Unknown dataset %r" % name)
    return np.array(X, dtype=float), np.array(y, dtype=float), units

# %%
#módosított modell tesztelő fv.
def test_model(X, y, model, param_grid):
    # load data
    #X, y, _ = load_regression_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    
    if model.__class__.__name__ == "SVR":
        sscaler = StandardScaler()
        X_train = sscaler.fit_transform(X_train)
        X_test = sscaler.transform(X_test)
        
    # train model on train split incl cross-validation for parameter selection
    gsmodel = GridSearchCV(model, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test)))
    return gsmodel.best_estimator_

# %%
#módosított autofeat modell tesztelő fv.
def test_autofeat(X, y, units, feateng_steps=2):
    # load data
    #X, y, units = load_regression_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    # run autofeat
    afreg = AutoFeatRegressor(verbose=1, feateng_steps=feateng_steps, units=units)
    # fit autofeat on less data, otherwise ridge reg model with xval will overfit on new features
    X_train_tr = afreg.fit_transform(X_train, y_train)
    X_test_tr = afreg.transform(X_test)
    print("autofeat new features:", len(afreg.new_feat_cols_))
    print("autofeat MSE on training data:", mean_squared_error(y_train, afreg.predict(X_train_tr)))
    print("autofeat MSE on test data:", mean_squared_error(y_test, afreg.predict(X_test_tr)))
    print("autofeat R^2 on training data:", r2_score(y_train, afreg.predict(X_train_tr)))
    print("autofeat R^2 on test data:", r2_score(y_test, afreg.predict(X_test_tr)))
    
    
    # train rreg on transformed train split incl cross-validation for parameter selection
    print("# Ridge Regression")
    rreg = Ridge()
    param_grid = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000.]}
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        gsmodel = GridSearchCV(rreg, param_grid, scoring='neg_mean_squared_error', cv=5)
        gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))
    
    
    print("# Random Forest")
    rforest = RandomForestRegressor(n_estimators=100, random_state=13)
    param_grid = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
    gsmodel = GridSearchCV(rforest, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))
    
    print("# SVR")
    svr = SVR(gamma="scale")
    param_grid = {"C": [1., 10., 25., 50., 100., 250.]}
    sscaler = StandardScaler()
    X_train_tr = sscaler.fit_transform(X_train_tr)
    X_test_tr = sscaler.transform(X_test_tr)

    gsmodel = GridSearchCV(svr, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))

# %%
#adatok beolvasása
dsname = 'boston'
print("####", dsname)
X, y, units = load_regression_dataset(dsname)
print(X.shape)
# Out:
# #### boston
# (506, 13)

# %%
randforreg = RandomForestRegressor(random_state=13)
randforreg.fit(X, y)
# define Boruta feature selection method
feat_selector = BorutaPy(randforreg, n_estimators='auto', verbose=2, random_state=11)
# find all relevant features
feat_selector.fit(X, y)
# call transform() on X to filter it down to selected features
XS = feat_selector.transform(X)
XS.shape
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	7
# Tentative: 	3
# Rejected: 	3
# Iteration: 	9 / 100
# Confirmed: 	7
# Tentative: 	3
# Rejected: 	3
# Iteration: 	10 / 100
# Confirmed: 	7
# Tentative: 	3
# Rejected: 	3
# Iteration: 	11 / 100
# Confirmed: 	7
# Tentative: 	3
# Rejected: 	3
# Iteration: 	12 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	13 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	14 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	15 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	16 / 100
# Confirmed: 	9
# Tentative: 	0
# Rejected: 	4
#
#
# BorutaPy finished running.
#
# Iteration: 	17 / 100
# Confirmed: 	9
# Tentative: 	0
# Rejected: 	4
# (506, 9)

# %%
#új változók generálása autofeattel
afreg = AutoFeatRegressor(verbose=1, feateng_steps=1, units=units)
#és a legjobbak kiválasztása
XS_af = afreg.fit_transform(XS, y)
XS_af.shape
# Out:
# [AutoFeat] The 1 step feature engineering process could generate up to 63 features.
# [AutoFeat] With 506 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 47 transformed features from 9 original features - done.
# [feateng] Generated altogether 47 new features in 1 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 16 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 18 features after 5 feature selection runs
# [featsel] 18 features after correlation filtering
# [featsel] 8 features after noise filtering
# [AutoFeat] Computing 2 new features.
# [AutoFeat]     2/    2 new features ...done.
# [AutoFeat] Final dataframe with 11 feature columns (2 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 31.509869639598172
# 44.609338 * 1/x008
# -0.631272 * x004
# -0.612169 * x006
# -0.316786 * x008
# -0.092410 * x000
# 0.007660 * x007
# 0.003439 * exp(x002)
# -0.002838 * x005
# [AutoFeat] Final score: 0.7908
# (506, 11)

# %%
randforreg = RandomForestRegressor(random_state=13)
randforreg.fit(XS_af, y)
# define Boruta feature selection method
feat_selector = BorutaPy(randforreg, n_estimators='auto', verbose=2, random_state=11)
# find all relevant features
feat_selector.fit(XS_af.iloc[:,:].values, y)
# call transform() on X to filter it down to selected features
XSS_af = feat_selector.transform(XS_af.iloc[:,:].values)
XSS_af.shape
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	11
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	11
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	11
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	11
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	11
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	11
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	11
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	13 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	14 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	15 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	16 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	17 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	18 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	19 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	20 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	21 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	22 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	23 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	24 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	25 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	0
# Iteration: 	26 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	27 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	28 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	29 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	30 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	31 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	32 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	33 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	34 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	35 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	36 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	37 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	38 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	39 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	40 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	41 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	42 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	43 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	44 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	45 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	46 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	47 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	48 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	49 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	50 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	51 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	52 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	53 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	54 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	55 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	56 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	57 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	58 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	59 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	60 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	61 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	62 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	63 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	64 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	65 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	66 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	67 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	68 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	69 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	70 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	71 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	72 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	73 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	74 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	75 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	76 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	77 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	78 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	79 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	80 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	81 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	82 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	83 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	84 / 100
# Confirmed: 	10
# Tentative: 	1
# Rejected: 	0
# Iteration: 	85 / 100
# Confirmed: 	11
# Tentative: 	0
# Rejected: 	0
#
#
# BorutaPy finished running.
#
# Iteration: 	86 / 100
# Confirmed: 	11
# Tentative: 	0
# Rejected: 	0
# (506, 11)

# %% [markdown]
# ## Adathalmaz tesztelése

# %%
dsname='boston'

# %%
#Ridge regresszió
print("####", dsname)
rreg = Ridge()
params = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000., 25000., 50000., 100000.]}
rreg = test_model(XSS_af, y, rreg, params)
# Out:
# #### boston
# best params: {'alpha': 1e-05}
# best score: -19.69714622891849
# MSE on training data: 17.492913456359272
# MSE on test data: 15.240722051579052
# R^2 on training data: 0.7942139301484967
# R^2 on test data: 0.8134785603503252

# %%
#SVR regresszió
print("####", dsname)
svr = SVR(gamma="scale")
params = {"C": [1., 10., 25., 50., 100., 250.]}
svr = test_model(XSS_af, y, svr, params)
# Out:
# #### boston
# best params: {'C': 25.0}
# best score: -12.3615169242313
# MSE on training data: 5.831271390778242
# MSE on test data: 8.493944587861536
# R^2 on training data: 0.9314011113849349
# R^2 on test data: 0.8960480502517693

# %%
#random forest regresszió
print("####", dsname)
rforest = RandomForestRegressor(n_estimators=100, random_state=13)
params = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
rforest = test_model(XSS_af, y, rforest, params)
# Out:
# #### boston
# best params: {'min_samples_leaf': 0.0001}
# best score: -10.400444731080242
# MSE on training data: 1.4349053638613856
# MSE on test data: 11.048889568627452
# R^2 on training data: 0.9831198195672471
# R^2 on test data: 0.8647797143799268

# %%
#autofeat regresszió 1 steppel
print("####", dsname)
test_autofeat(XSS_af, y, units, feateng_steps=1)
# Out:
# #### boston
# [AutoFeat] The 1 step feature engineering process could generate up to 77 features.
# [AutoFeat] With 404 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 58 transformed features from 11 original features - done.
# [feateng] Generated altogether 58 new features in 1 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 24 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 15 features after 5 feature selection runs
# [featsel] 15 features after correlation filtering
# [featsel] 12 features after noise filtering
# [AutoFeat] Computing 4 new features.
# [AutoFeat]     4/    4 new features ...done.
# [AutoFeat] Final dataframe with 15 feature columns (4 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 36.34036200941121
# 340.716905 * 1/x010
# 25.025974 * x009
# -22.967887 * x001
# 19.292949 * 1/x004
# 0.732285 * log(x000)
# -0.476757 * x008
# -0.472066 * x006
# -0.197777 * x000
# 0.007429 * x010
# 0.005595 * x007
# -0.005534 * x005
# [AutoFeat] Final score: 0.8388
# [AutoFeat] Computing 4 new features.
# [AutoFeat]     4/    4 new features ...done.
# autofeat new features: 4
# autofeat MSE on training data: 13.701154579962338
# autofeat MSE on test data: 15.747071150626986
# autofeat R^2 on training data: 0.8388200593073085
# autofeat R^2 on test data: 0.807281677906035
# # Ridge Regression
# best params: {'alpha': 0.01}
# best score: -16.396439736289825
# MSE on training data: 13.618701248822163
# MSE on test data: 15.478718992405529
# R^2 on training data: 0.8397900376361804
# R^2 on test data: 0.810565868163896
# # Random Forest
# best params: {'min_samples_leaf': 0.0001}
# best score: -10.335896030277771
# MSE on training data: 1.3873937673267323
# MSE on test data: 11.315444401960786
# R^2 on training data: 0.9836787444568962
# R^2 on test data: 0.8615175204306735
# # SVR
# best params: {'C': 25.0}
# best score: -11.528696150043112
# MSE on training data: 3.9392403569883725
# MSE on test data: 8.909188627868343
# R^2 on training data: 0.9536589034589676
# R^2 on test data: 0.8909661442970581

# %%
#autofeat regresszió 2 steppel
warnings.simplefilter("ignore")
print("####", dsname)
test_autofeat(XSS_af, y, units, feateng_steps=2)
# Out:
# #### boston
# [AutoFeat] The 2 step feature engineering process could generate up to 3003 features.
# [AutoFeat] With 404 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 58 transformed features from 11 original features - done.
# [feateng] Step 2: first combination of features
# [feateng] Generated 2294 feature combinations from 2346 original feature tuples - done.
# [feateng] Generated altogether 2361 new features in 2 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 1074 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 39 features after 5 feature selection runs
# [featsel] 23 features after correlation filtering
# [featsel] 10 features after noise filtering
# [AutoFeat] Computing 9 new features.
# [AutoFeat]     9/    9 new features ...done.
# [AutoFeat] Final dataframe with 20 feature columns (9 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 16.928156205013174
# 71.381092 * sqrt(x010)/x005
# 69.001717 * x009/x004
# -0.201088 * x001**2/x009
# -0.093041 * x000
# 0.004777 * x006**2*log(x009)
# 0.000160 * x007*sqrt(x010)
# 0.000112 * x005**2*x009
# [AutoFeat] Final score: 0.8718
# [AutoFeat] Computing 9 new features.
# [AutoFeat]     9/    9 new features ...done.
# autofeat new features: 9
# autofeat MSE on training data: 10.895380910749282
# autofeat MSE on test data: 12.361313872009392
# autofeat R^2 on training data: 0.8718270902813448
# autofeat R^2 on test data: 0.8487177935818464
# # Ridge Regression
# best params: {'alpha': 0.01}
# best score: -12.022214731410351
# MSE on training data: 9.800537429005647
# MSE on test data: 10.622910967378
# R^2 on training data: 0.8847067936979676
# R^2 on test data: 0.8699929937571182
# # Random Forest
# best params: {'min_samples_leaf': 0.0001}
# best score: -11.069793616141972
# MSE on training data: 1.4509722648514838
# MSE on test data: 11.403838078431368
# R^2 on training data: 0.9829308090620678
# R^2 on test data: 0.8604357268164718
# # SVR
# best params: {'C': 25.0}
# best score: -12.864451625895509
# MSE on training data: 4.384317517552391
# MSE on test data: 8.563574705115967
# R^2 on training data: 0.9484230300933539
# R^2 on test data: 0.8951958918258549

# %%
#sokáig futna
#autofeat regresszió 3 steppel
#print("####", dsname)
#test_autofeat(XSS_af, y, units, feateng_steps=3)
