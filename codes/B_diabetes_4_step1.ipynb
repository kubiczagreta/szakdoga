# %%
#pip install autofeat

# %%
import os
import sys
import warnings
import sklearn
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston, load_diabetes
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from autofeat import AutoFeatRegressor
from boruta import BorutaPy

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# ignore all future warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
np.seterr(divide = 'ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
#regr adatbeolvasó fv.
def load_regression_dataset(name):
    units = {}
    if name == "boston":
        X, y = load_boston(True)
    elif name == "diabetes":
        X, y = load_diabetes(True)
    else:
        raise RuntimeError("Unknown dataset %r" % name)
    return np.array(X, dtype=float), np.array(y, dtype=float), units

# %%
#módosított modell tesztelő fv.
def test_model(X, y, model, param_grid):
    # load data
    #X, y, _ = load_regression_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    
    if model.__class__.__name__ == "SVR":
        sscaler = StandardScaler()
        X_train = sscaler.fit_transform(X_train)
        X_test = sscaler.transform(X_test)
        
    # train model on train split incl cross-validation for parameter selection
    gsmodel = GridSearchCV(model, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test)))
    return gsmodel.best_estimator_

# %%
#módosított autofeat modell tesztelő fv.
def test_autofeat(X, y, units, feateng_steps=2):
    # load data
    #X, y, units = load_regression_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    # run autofeat
    afreg = AutoFeatRegressor(verbose=1, feateng_steps=feateng_steps, units=units)
    # fit autofeat on less data, otherwise ridge reg model with xval will overfit on new features
    X_train_tr = afreg.fit_transform(X_train, y_train)
    X_test_tr = afreg.transform(X_test)
    print("autofeat new features:", len(afreg.new_feat_cols_))
    print("autofeat MSE on training data:", mean_squared_error(y_train, afreg.predict(X_train_tr)))
    print("autofeat MSE on test data:", mean_squared_error(y_test, afreg.predict(X_test_tr)))
    print("autofeat R^2 on training data:", r2_score(y_train, afreg.predict(X_train_tr)))
    print("autofeat R^2 on test data:", r2_score(y_test, afreg.predict(X_test_tr)))
    
    
    # train rreg on transformed train split incl cross-validation for parameter selection
    print("# Ridge Regression")
    rreg = Ridge()
    param_grid = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000.]}
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        gsmodel = GridSearchCV(rreg, param_grid, scoring='neg_mean_squared_error', cv=5)
        gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))
    
    
    print("# Random Forest")
    rforest = RandomForestRegressor(n_estimators=100, random_state=13)
    param_grid = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
    gsmodel = GridSearchCV(rforest, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))
    
    print("# SVR")
    svr = SVR(gamma="scale")
    param_grid = {"C": [1., 10., 25., 50., 100., 250.]}
    sscaler = StandardScaler()
    X_train_tr = sscaler.fit_transform(X_train_tr)
    X_test_tr = sscaler.transform(X_test_tr)

    gsmodel = GridSearchCV(svr, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))

# %%
#adatok beolvasása és splitelése
dsname = 'diabetes'
print("####", dsname)
X, y, units = load_regression_dataset(dsname)
print(X.shape)
# Out:
# #### diabetes
# (442, 10)

# %%
randforreg = RandomForestRegressor(random_state=13)
randforreg.fit(X, y)
# define Boruta feature selection method
feat_selector = BorutaPy(randforreg, n_estimators='auto', verbose=2, random_state=11)
# find all relevant features
feat_selector.fit(X, y)
# call transform() on X to filter it down to selected features
XS = feat_selector.transform(X)
XS.shape
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	5
# Iteration: 	9 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	5
# Iteration: 	10 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	5
# Iteration: 	11 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	5
# Iteration: 	12 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	5
# Iteration: 	13 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	5
# Iteration: 	14 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	5
# Iteration: 	15 / 100
# Confirmed: 	3
# Tentative: 	2
# Rejected: 	5
# Iteration: 	16 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	17 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	18 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	19 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	20 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	21 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	22 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	23 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	24 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	25 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	26 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	27 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	28 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	29 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	30 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	31 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	32 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	33 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	34 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	35 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	36 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	37 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	38 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	39 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	40 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	41 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	42 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	43 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	44 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	45 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	46 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	47 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	48 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	49 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	50 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	51 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	52 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	53 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	54 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	55 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	56 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	57 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	58 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	59 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	60 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	61 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	62 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	63 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	64 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	65 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	66 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	67 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	68 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	69 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	70 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	71 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	72 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	73 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	74 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	75 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	76 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	77 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	78 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	79 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	80 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	81 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	82 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	83 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	84 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	85 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	86 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	87 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	88 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	89 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	90 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	91 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	92 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	93 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	94 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	95 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	96 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	97 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	98 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# Iteration: 	99 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	5
# (442, 4)

# %%
#új változók generálása autofeattel
afreg = AutoFeatRegressor(verbose=1, feateng_steps=1, units=units)
#és a legjobbak kiválasztása
XS_af = afreg.fit_transform(XS, y)
XS_af.shape
# Out:
# [AutoFeat] The 1 step feature engineering process could generate up to 28 features.
# [AutoFeat] With 442 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 20 transformed features from 4 original features - done.
# [feateng] Generated altogether 20 new features in 1 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 16 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 10 features after 5 feature selection runs
# [featsel] 9 features after correlation filtering
# [featsel] 6 features after noise filtering
# [AutoFeat] Computing 3 new features.
# [AutoFeat]     3/    3 new features ...done.
# [AutoFeat] Final dataframe with 7 feature columns (3 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 139.02325916837248
# -31562.799938 * x002**3
# 2070.807934 * x000**2
# 770.934221 * x002
# 500.830217 * x000
# 280.205380 * x001
# 254.121557 * Abs(x003)
# [AutoFeat] Final score: 0.5053
# (442, 7)

# %%
randforreg = RandomForestRegressor(random_state=13)
randforreg.fit(XS_af, y)
# define Boruta feature selection method
feat_selector = BorutaPy(randforreg, n_estimators='auto', verbose=2, random_state=11)
# find all relevant features
feat_selector.fit(XS_af.iloc[:,:].values, y)
# call transform() on X to filter it down to selected features
XSS_af = feat_selector.transform(XS_af.iloc[:,:].values)
XSS_af.shape
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	7
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	7
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	7
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	7
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	7
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	7
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	7
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	1
# Iteration: 	9 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	1
# Iteration: 	10 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	1
# Iteration: 	11 / 100
# Confirmed: 	4
# Tentative: 	2
# Rejected: 	1
# Iteration: 	12 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	13 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	14 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	15 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	16 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	17 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	18 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	19 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	20 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	21 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	22 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	23 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	24 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	25 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	26 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	27 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	28 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	29 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	30 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	31 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	32 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	33 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	34 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	35 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	36 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	37 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	38 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	39 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	40 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	41 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	42 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	43 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	44 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	45 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	46 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	47 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	48 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	49 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	50 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	51 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	52 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	53 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	54 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	55 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	56 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	57 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	58 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	59 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	60 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	61 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	62 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	63 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	64 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	65 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	66 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	67 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	68 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	69 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	70 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	71 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	72 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	73 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	74 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	75 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	76 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	77 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	78 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	79 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	80 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	81 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	82 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	83 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	84 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	85 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	86 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	87 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	88 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	89 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	90 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	91 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	92 / 100
# Confirmed: 	4
# Tentative: 	1
# Rejected: 	2
# Iteration: 	93 / 100
# Confirmed: 	5
# Tentative: 	0
# Rejected: 	2
#
#
# BorutaPy finished running.
#
# Iteration: 	94 / 100
# Confirmed: 	5
# Tentative: 	0
# Rejected: 	2
# (442, 5)

# %% [markdown]
# ## Adathalmaz tesztelése

# %%
dsname='diabetes'

# %%
#Ridge regresszió
print("####", dsname)
rreg = Ridge()
params = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000., 25000., 50000., 100000.]}
rreg = test_model(XSS_af, y, rreg, params)
# Out:
# #### diabetes
# best params: {'alpha': 1e-05}
# best score: -3139.048328329742
# MSE on training data: 2987.7712953501004
# MSE on test data: 3280.7156136311824
# R^2 on training data: 0.5136110370109136
# R^2 on test data: 0.3511508234244992

# %%
#SVR regresszió
print("####", dsname)
svr = SVR(gamma="scale")
params = {"C": [1., 10., 25., 50., 100., 250.]}
svr = test_model(XSS_af, y, svr, params)
# Out:
# #### diabetes
# best params: {'C': 25.0}
# best score: -3323.170349705336
# MSE on training data: 2758.183646603716
# MSE on test data: 3476.2526671092073
# R^2 on training data: 0.5509863537102365
# R^2 on test data: 0.31247814615492364

# %%
#random forest regresszió
print("####", dsname)
rforest = RandomForestRegressor(n_estimators=100, random_state=13)
params = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
rforest = test_model(XSS_af, y, rforest, params)
# Out:
# #### diabetes
# best params: {'min_samples_leaf': 0.05}
# best score: -3368.395081756684
# MSE on training data: 2595.3140594756883
# MSE on test data: 3263.464320717948
# R^2 on training data: 0.577500421138674
# R^2 on test data: 0.3545627275697737

# %%
#autofeat regresszió 1 steppel
print("####", dsname)
test_autofeat(XSS_af, y, units, feateng_steps=1)
# Out:
# #### diabetes
# [AutoFeat] The 1 step feature engineering process could generate up to 35 features.
# [AutoFeat] With 353 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 23 transformed features from 5 original features - done.
# [feateng] Generated altogether 25 new features in 1 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 18 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 11 features after 5 feature selection runs
# [featsel] 11 features after correlation filtering
# [featsel] 10 features after noise filtering
# [AutoFeat] Computing 6 new features.
# [AutoFeat]     6/    6 new features ...done.
# [AutoFeat] Final dataframe with 11 feature columns (6 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 138.83530064338984
# 14317.822028 * x001**3
# 2418.196083 * x003**2
# 1439.079331 * x000**2
# 531.442670 * x002
# 525.939947 * x000
# 190.875231 * x001
# 133.844057 * Abs(x001)
# 39.275865 * x003
# 0.019190 * 1/x000
# 0.018256 * 1/x002
# [AutoFeat] Final score: 0.5380
# [AutoFeat] Computing 6 new features.
# [AutoFeat]     6/    6 new features ...done.
# autofeat new features: 6
# autofeat MSE on training data: 2837.8090203149286
# autofeat MSE on test data: 3339.1378496955094
# autofeat R^2 on training data: 0.538023881312403
# autofeat R^2 on test data: 0.3395962651426
# # Ridge Regression
# best params: {'alpha': 1e-05}
# best score: -3071.7445050726824
# MSE on training data: 2788.2556257051933
# MSE on test data: 3323.605244835401
# R^2 on training data: 0.5460908388651209
# R^2 on test data: 0.3426682528003169
# # Random Forest
# best params: {'min_samples_leaf': 0.05}
# best score: -3394.9340426129957
# MSE on training data: 2543.4710484637258
# MSE on test data: 3244.6139538083285
# R^2 on training data: 0.5859401127588404
# R^2 on test data: 0.3582908913266788
# # SVR
# best params: {'C': 25.0}
# best score: -3573.972860023999
# MSE on training data: 2724.4185617065755
# MSE on test data: 3701.19030179149
# R^2 on training data: 0.5564830812053825
# R^2 on test data: 0.26799071833947274

# %%
#autofeat regresszió 2 steppel
print("####", dsname)
test_autofeat(XSS_af, y, units, feateng_steps=2)
# Out:
# #### diabetes
# [AutoFeat] The 2 step feature engineering process could generate up to 630 features.
# [AutoFeat] With 353 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 23 transformed features from 5 original features - done.
# [feateng] Step 2: first combination of features
# [feateng] Generated 321 feature combinations from 378 original feature tuples - done.
# [feateng] Generated altogether 387 new features in 2 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 199 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 17 features after 5 feature selection runs
# [featsel] 16 features after correlation filtering
# [featsel] 7 features after noise filtering
# [AutoFeat] Computing 7 new features.
# [AutoFeat]     7/    7 new features ...done.
# [AutoFeat] Final dataframe with 12 feature columns (7 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# -413.48799577943737
# 27304.088705 * x000**2*Abs(x001)
# 2613.703851 * x003**2
# 300.955753 * exp(x000)*exp(x001)
# 254.714244 * exp(x000)*exp(x002)
# 16.755029 * Abs(x002)/x002
# -14.333315 * x001**2/x003
# 0.563819 * x003/x002
# [AutoFeat] Final score: 0.5572
# [AutoFeat] Computing 7 new features.
# [AutoFeat]     7/    7 new features ...done.
# autofeat new features: 7
# autofeat MSE on training data: 2720.0620494988793
# autofeat MSE on test data: 3293.7937371868024
# autofeat R^2 on training data: 0.5571922919332077
# autofeat R^2 on test data: 0.34856427503092335
# # Ridge Regression
# best params: {'alpha': 0.001}
# best score: -2991.5390454508715
# MSE on training data: 2717.5210892929395
# MSE on test data: 3294.630891167596
# R^2 on training data: 0.5576059430722649
# R^2 on test data: 0.34839870546163554
# # Random Forest
# best params: {'min_samples_leaf': 0.05}
# best score: -3195.6558862232223
# MSE on training data: 2273.5425580410138
# MSE on test data: 3380.9763209563903
# R^2 on training data: 0.6298826456904074
# R^2 on test data: 0.3313215894852505
# # SVR
# best params: {'C': 25.0}
# best score: -3493.2335015347635
# MSE on training data: 2702.3179177613124
# MSE on test data: 3505.205101989269
# R^2 on training data: 0.5600809165907941
# R^2 on test data: 0.30675202851957295

# %%
#autofeat regresszió 3 steppel
print("####", dsname)
test_autofeat(XSS_af, y, units, feateng_steps=3)
# Out:
# #### diabetes
# [AutoFeat] The 3 step feature engineering process could generate up to 14910 features.
# [AutoFeat] With 353 data points this new feature matrix would use about 0.02 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 23 transformed features from 5 original features - done.
# [feateng] Step 2: first combination of features
# [feateng] Generated 1396 feature combinations from 378 original feature tuples - done.
# [feateng] Step 3: transformation of new features
# [feateng] Generated 5794 transformed features from 1396 original features - done.
# [feateng] Generated altogether 7828 new features in 3 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 3387 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 24 features after 5 feature selection runs
# [featsel] 21 features after correlation filtering
# [featsel] 8 features after noise filtering
# [AutoFeat] Computing 8 new features.
# [AutoFeat]     8/    8 new features ...done.
# [AutoFeat] Final dataframe with 13 feature columns (8 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# -317.3989318573409
# 243.281752 * exp(x000)*exp(x001)
# 207.526702 * exp(x000)*exp(x002)
# 198.022802 * Abs(x000 + Abs(x003))
# 120.446222 * Abs(x001 + Abs(x003))
# 44.425196 * Abs(x002 + Abs(x003))
# 11.661287 * Abs(x002)/x002
# 1.305770 * x002/Abs(x000)
# 0.064035 * 1/(x000 + x001)
# [AutoFeat] Final score: 0.5636
# [AutoFeat] Computing 8 new features.
# [AutoFeat]     8/    8 new features ...done.
# autofeat new features: 8
# autofeat MSE on training data: 2680.8984815597155
# autofeat MSE on test data: 123739.78626113787
# autofeat R^2 on training data: 0.5635678559619968
# autofeat R^2 on test data: -23.472849183139772
# # Ridge Regression
# best params: {'alpha': 0.1}
# best score: -2886.739318006573
# MSE on training data: 2679.0416471792473
# MSE on test data: 133994.22457753067
# R^2 on training data: 0.5638701360428597
# R^2 on test data: -25.500938368984002
# # Random Forest
# best params: {'min_samples_leaf': 0.05}
# best score: -3196.666172636119
# MSE on training data: 2296.3074943441943
# MSE on test data: 3483.8073460058713
# R^2 on training data: 0.6261766680012018
# R^2 on test data: 0.31098400653458425
# # SVR
# best params: {'C': 25.0}
# best score: -3234.4098504847834
# MSE on training data: 2578.8585295271105
# MSE on test data: 3687.8541805426325
# R^2 on training data: 0.5801792701387902
# R^2 on test data: 0.2706282926708409
