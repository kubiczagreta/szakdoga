# %%
import os
import sys
import warnings
import sklearn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris, load_wine, load_breast_cancer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy

from autofeat import AutoFeatClassifier

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# ignore all future warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
np.seterr(divide = 'ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
# same interface for loading all datasets
def load_classification_dataset(name):
    # load one of the datasets as X and y
    units = {}
    if name == "iris":
        # sklearn iris housing dataset
        X, y = load_iris(True)

    elif name == "wine":
        # sklearn wine dataset
        X, y = load_wine(True)
    
    elif name == "breast_cancer":
        # sklearn breast_cancer dataset
        X, y = load_breast_cancer(True)

    else:
        raise RuntimeError("Unknown dataset %r" % name)
    return np.array(X, dtype=float), np.array(y, dtype=float), units

# %%
def test_model(X, y, model, param_grid):
    # load data
    #X, y, _ = load_classification_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    
    if model.__class__.__name__ == "SVC":
        sscaler = StandardScaler()
        X_train = sscaler.fit_transform(X_train)
        X_test = sscaler.transform(X_test)
    
    # train model on train split incl cross-validation for parameter selection
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        gsmodel = GridSearchCV(model, param_grid, cv=5)
        gsmodel.fit(X_train, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("Acc. on training data:", accuracy_score(y_train, gsmodel.predict(X_train)))
    print("Acc. on test data:", accuracy_score(y_test, gsmodel.predict(X_test)))
    return gsmodel.best_estimator_

def test_autofeat(X, y, units, feateng_steps=2):
    # load data
    #X, y, units = load_classification_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    # run autofeat
    afclas = AutoFeatClassifier(verbose=1, feateng_steps=feateng_steps, units=units)
    # fit autofeat on less data, otherwise ridge reg model with xval will overfit on new features
    X_train_tr = afclas.fit_transform(X_train, y_train)
    X_test_tr = afclas.transform(X_test)
    print("autofeat new features:", len(afclas.new_feat_cols_))
    print("autofeat Acc. on training data:", accuracy_score(y_train, afclas.predict(X_train_tr)))
    print("autofeat Acc. on test data:", accuracy_score(y_test, afclas.predict(X_test_tr)))
    
    # train rreg on transformed train split incl cross-validation for parameter selection
    print("# Logistic Regression")
    rreg = LogisticRegression(class_weight="balanced")
    param_grid = {"C": np.logspace(-4, 4, 10)}
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        gsmodel = GridSearchCV(rreg, param_grid, cv=5)
        gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("Acc. on training data:", accuracy_score(y_train, gsmodel.predict(X_train_tr)))
    print("Acc. on test data:", accuracy_score(y_test, gsmodel.predict(X_test_tr)))
    
    print("# Random Forest")
    rforest = RandomForestClassifier(n_estimators=100, random_state=13)
    param_grid = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
    gsmodel = GridSearchCV(rforest, param_grid, cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("Acc. on training data:", accuracy_score(y_train, gsmodel.predict(X_train_tr)))
    print("Acc. on test data:", accuracy_score(y_test, gsmodel.predict(X_test_tr)))
    
    print("# SVC")
    svc = SVC(gamma="scale", class_weight="balanced")
    param_grid = {"C": [1., 10., 25., 50., 100., 250.]}
    sscaler = StandardScaler()
    X_train_tr = sscaler.fit_transform(X_train_tr)
    X_test_tr = sscaler.transform(X_test_tr)
    gsmodel = GridSearchCV(svc, param_grid, cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("Acc. on training data:", accuracy_score(y_train, gsmodel.predict(X_train_tr)))
    print("Acc. on test data:", accuracy_score(y_test, gsmodel.predict(X_test_tr)))

# %%
dsname = 'breast_cancer'
print("####", dsname)
X, y, _ = load_classification_dataset(dsname)
print(X.shape, np.unique(y))
# Out:
# #### breast_cancer
# (569, 30) [0. 1.]

# %%
randforclas = RandomForestClassifier(class_weight='balanced', random_state=13)
randforclas.fit(X, y)
# define Boruta feature selection method
feat_selector = BorutaPy(randforclas, n_estimators='auto', verbose=2, random_state=11)
# find all relevant features
feat_selector.fit(X, y)
# call transform() on X to filter it down to selected features
XS = feat_selector.transform(X)
XS.shape
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	30
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	19
# Tentative: 	10
# Rejected: 	1
# Iteration: 	11 / 100
# Confirmed: 	19
# Tentative: 	10
# Rejected: 	1
# Iteration: 	12 / 100
# Confirmed: 	20
# Tentative: 	9
# Rejected: 	1
# Iteration: 	13 / 100
# Confirmed: 	20
# Tentative: 	9
# Rejected: 	1
# Iteration: 	14 / 100
# Confirmed: 	20
# Tentative: 	9
# Rejected: 	1
# Iteration: 	15 / 100
# Confirmed: 	20
# Tentative: 	9
# Rejected: 	1
# Iteration: 	16 / 100
# Confirmed: 	21
# Tentative: 	8
# Rejected: 	1
# Iteration: 	17 / 100
# Confirmed: 	21
# Tentative: 	8
# Rejected: 	1
# Iteration: 	18 / 100
# Confirmed: 	21
# Tentative: 	8
# Rejected: 	1
# Iteration: 	19 / 100
# Confirmed: 	21
# Tentative: 	8
# Rejected: 	1
# Iteration: 	20 / 100
# Confirmed: 	21
# Tentative: 	7
# Rejected: 	2
# Iteration: 	21 / 100
# Confirmed: 	21
# Tentative: 	7
# Rejected: 	2
# Iteration: 	22 / 100
# Confirmed: 	21
# Tentative: 	7
# Rejected: 	2
# Iteration: 	23 / 100
# Confirmed: 	21
# Tentative: 	7
# Rejected: 	2
# Iteration: 	24 / 100
# Confirmed: 	21
# Tentative: 	7
# Rejected: 	2
# Iteration: 	25 / 100
# Confirmed: 	21
# Tentative: 	7
# Rejected: 	2
# Iteration: 	26 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	27 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	28 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	29 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	30 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	31 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	32 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	33 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	34 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	35 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	36 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	37 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	38 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	39 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	40 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	41 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	42 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	43 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	44 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	45 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	46 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	47 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	48 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	49 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	50 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	51 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	52 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	53 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	54 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	55 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	56 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	57 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	58 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	59 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	60 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	61 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	62 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	63 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	64 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	65 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	66 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	67 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	68 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	69 / 100
# Confirmed: 	22
# Tentative: 	6
# Rejected: 	2
# Iteration: 	70 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3
# Iteration: 	71 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3
# Iteration: 	72 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3
# Iteration: 	73 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3
# Iteration: 	74 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3
# Iteration: 	75 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3
# Iteration: 	76 / 100
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	3
# Iteration: 	77 / 100
# Confirmed: 	22
# Tentative: 	4
# Rejected: 	4
# Iteration: 	78 / 100
# Confirmed: 	22
# Tentative: 	4
# Rejected: 	4
# Iteration: 	79 / 100
# Confirmed: 	22
# Tentative: 	4
# Rejected: 	4
# Iteration: 	80 / 100
# Confirmed: 	23
# Tentative: 	3
# Rejected: 	4
# Iteration: 	81 / 100
# Confirmed: 	23
# Tentative: 	3
# Rejected: 	4
# Iteration: 	82 / 100
# Confirmed: 	23
# Tentative: 	3
# Rejected: 	4
# Iteration: 	83 / 100
# Confirmed: 	23
# Tentative: 	2
# Rejected: 	5
# Iteration: 	84 / 100
# Confirmed: 	23
# Tentative: 	2
# Rejected: 	5
# Iteration: 	85 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	86 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	87 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	88 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	89 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	90 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	91 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	92 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	93 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	94 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	95 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	96 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	97 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	98 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
# Iteration: 	99 / 100
# Confirmed: 	23
# Tentative: 	1
# Rejected: 	6
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	23
# Tentative: 	0
# Rejected: 	6
# (569, 23)

# %%
print("####", dsname)
rreg = LogisticRegression(class_weight="balanced")
params = {"C": np.logspace(-4, 4, 10)}
rreg = test_model(XS, y, rreg, params)
# Out:
# #### breast_cancer
# best params: {'C': 21.54434690031882}
# best score: 0.9472527472527472
# Acc. on training data: 0.9626373626373627
# Acc. on test data: 0.9473684210526315

# %%
print("####", dsname)
rforest = RandomForestClassifier(n_estimators=100, random_state=13)
params = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
rforest = test_model(XS, y, rforest, params)
# Out:
# #### breast_cancer
# best params: {'min_samples_leaf': 0.0001}
# best score: 0.9604395604395604
# Acc. on training data: 1.0
# Acc. on test data: 0.9298245614035088

# %%
print("####", dsname)
svc = SVC(gamma="scale", class_weight="balanced")
params = {"C": [1., 10., 25., 50., 100., 250.]}
svc = test_model(XS, y, svc, params)
# Out:
# #### breast_cancer
# best params: {'C': 1.0}
# best score: 0.9736263736263737
# Acc. on training data: 0.9824175824175824
# Acc. on test data: 0.9649122807017544

# %%
print("####", dsname)
test_autofeat(XS, y, _, feateng_steps=1)
# Out:
# #### breast_cancer
# [AutoFeat] The 1 step feature engineering process could generate up to 161 features.
# [AutoFeat] With 455 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 115 transformed features from 23 original features - done.
# [feateng] Generated altogether 122 new features in 1 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 45 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 14 features after 5 feature selection runs
# [featsel] 10 features after correlation filtering
# [featsel] 7 features after noise filtering
# [AutoFeat] Computing 2 new features.
# [AutoFeat]     2/    2 new features ...done.
# [AutoFeat] Final dataframe with 25 feature columns (2 new).
# [AutoFeat] Training final classification model.
# [AutoFeat] Trained model: largest coefficients:
# [35.34725009]
# 30.219075 * x020
# 24.011531 * x017
# 6.911637 * x008
# 2.108999 * x020**3
# 0.266066 * x014
# 0.175442 * x015
# 0.044884 * 1/x016
# [AutoFeat] Final score: 0.9626
# [AutoFeat] Computing 2 new features.
# [AutoFeat]     2/    2 new features ...done.
# autofeat new features: 2
# autofeat Acc. on training data: 0.9626373626373627
# autofeat Acc. on test data: 0.9824561403508771
# # Logistic Regression
# best params: {'C': 21.54434690031882}
# best score: 0.9516483516483516
# Acc. on training data: 0.9648351648351648
# Acc. on test data: 0.9473684210526315
# # Random Forest
# best params: {'min_samples_leaf': 0.0001}
# best score: 0.9670329670329669
# Acc. on training data: 1.0
# Acc. on test data: 0.9385964912280702
# # SVC
# best params: {'C': 1.0}
# best score: 0.9736263736263735
# Acc. on training data: 0.9846153846153847
# Acc. on test data: 0.9649122807017544

# %%
print("####", dsname)
warnings.simplefilter("ignore")
test_autofeat(XS, y, _, feateng_steps=2)
# Out:
# #### breast_cancer
# [AutoFeat] The 2 step feature engineering process could generate up to 13041 features.
# [AutoFeat] With 455 data points this new feature matrix would use about 0.02 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 115 transformed features from 23 original features - done.
# [feateng] Step 2: first combination of features
# [feateng] Generated 9310 feature combinations from 9453 original feature tuples - done.
# [feateng] Generated altogether 9502 new features in 2 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 4142 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 20 features after 5 feature selection runs
# [featsel] 11 features after correlation filtering
# [featsel] 10 features after noise filtering
# [AutoFeat] Computing 9 new features.
# [AutoFeat]     9/    9 new features ...done.
# [AutoFeat] Final dataframe with 32 feature columns (9 new).
# [AutoFeat] Training final classification model.
# [AutoFeat] Trained model: largest coefficients:
# [72.39155274]
# 16.417577 * sqrt(x017)*log(x013)
# 14.564660 * x020
# 5.277095 * exp(x021)*log(x013)
# 4.128652 * x007/x005
# 3.257008 * x006/x005
# 3.137542 * log(x013)*log(x014)
# 0.493945 * x020**3/x009
# 0.322773 * sqrt(x021)*log(x010)
# 0.060524 * sqrt(x007)*x014
# 0.010954 * x009**2/x018
# [AutoFeat] Final score: 0.9868
# [AutoFeat] Computing 9 new features.
# [AutoFeat]     9/    9 new features ...done.
# autofeat new features: 9
# autofeat Acc. on training data: 0.9868131868131869
# autofeat Acc. on test data: 0.9824561403508771
# # Logistic Regression
# best params: {'C': 1291.5496650148827}
# best score: 0.9780219780219781
# Acc. on training data: 0.9802197802197802
# Acc. on test data: 0.9649122807017544
# # Random Forest
# best params: {'min_samples_leaf': 0.0001}
# best score: 0.9758241758241757
# Acc. on training data: 1.0
# Acc. on test data: 0.9473684210526315
# # SVC
# best params: {'C': 1.0}
# best score: 0.9758241758241757
# Acc. on training data: 0.9868131868131869
# Acc. on test data: 0.9649122807017544

# %%
#túl sokáig futna
#print("####", dsname)
#warnings.simplefilter("ignore")
#test_autofeat(XS, y, _, feateng_steps=3)
