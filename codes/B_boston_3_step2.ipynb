# %%
#pip install autofeat

# %%
import os
import sys
import warnings
import sklearn
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston, load_diabetes
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from autofeat import AutoFeatRegressor
from boruta import BorutaPy

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# ignore all future warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
np.seterr(divide = 'ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
#regr adatbeolvasó fv.
def load_regression_dataset(name):
    units = {}
    if name == "boston":
        X, y = load_boston(True)
    elif name == "diabetes":
        X, y = load_diabetes(True)
    else:
        raise RuntimeError("Unknown dataset %r" % name)
    return np.array(X, dtype=float), np.array(y, dtype=float), units

# %%
#módosított modell tesztelő fv.
def test_model(X, y, model, param_grid):
    # load data
    #X, y, _ = load_regression_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    
    if model.__class__.__name__ == "SVR":
        sscaler = StandardScaler()
        X_train = sscaler.fit_transform(X_train)
        X_test = sscaler.transform(X_test)
        
    # train model on train split incl cross-validation for parameter selection
    gsmodel = GridSearchCV(model, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test)))
    return gsmodel.best_estimator_

# %%
#módosított autofeat modell tesztelő fv.
def test_autofeat(X, y, units, feateng_steps=2):
    # load data
    #X, y, units = load_regression_dataset(dataset)
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    # run autofeat
    afreg = AutoFeatRegressor(verbose=1, feateng_steps=feateng_steps, units=units)
    # fit autofeat on less data, otherwise ridge reg model with xval will overfit on new features
    X_train_tr = afreg.fit_transform(X_train, y_train)
    X_test_tr = afreg.transform(X_test)
    print("autofeat new features:", len(afreg.new_feat_cols_))
    print("autofeat MSE on training data:", mean_squared_error(y_train, afreg.predict(X_train_tr)))
    print("autofeat MSE on test data:", mean_squared_error(y_test, afreg.predict(X_test_tr)))
    print("autofeat R^2 on training data:", r2_score(y_train, afreg.predict(X_train_tr)))
    print("autofeat R^2 on test data:", r2_score(y_test, afreg.predict(X_test_tr)))
    
    
    # train rreg on transformed train split incl cross-validation for parameter selection
    print("# Ridge Regression")
    rreg = Ridge()
    param_grid = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000.]}
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        gsmodel = GridSearchCV(rreg, param_grid, scoring='neg_mean_squared_error', cv=5)
        gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))
    
    
    print("# Random Forest")
    rforest = RandomForestRegressor(n_estimators=100, random_state=13)
    param_grid = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
    gsmodel = GridSearchCV(rforest, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))
    
    
    print("# SVR")
    svr = SVR(gamma="scale")
    param_grid = {"C": [1., 10., 25., 50., 100., 250.]}
    sscaler = StandardScaler()
    X_train_tr = sscaler.fit_transform(X_train_tr)
    X_test_tr = sscaler.transform(X_test_tr)
    gsmodel = GridSearchCV(svr, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))

# %%
#adatok beolvasása
X, y, units = load_regression_dataset("boston")
#új változók generálása autofeattel
afreg = AutoFeatRegressor(verbose=1, feateng_steps=2, units=units)
#és a legjobbak kiválasztása
X_af = afreg.fit_transform(X, y)
X_af.shape
# Out:
# [AutoFeat] The 2 step feature engineering process could generate up to 4186 features.
# [AutoFeat] With 506 data points this new feature matrix would use about 0.01 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 60 transformed features from 13 original features - done.
# [feateng] Step 2: first combination of features
# [feateng] Generated 2583 feature combinations from 2628 original feature tuples - done.
# [feateng] Generated altogether 2645 new features in 2 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 1198 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 62 features after 5 feature selection runs
# [featsel] 45 features after correlation filtering
# [featsel] 20 features after noise filtering
# [AutoFeat] Computing 19 new features.
# [AutoFeat]    19/   19 new features ...done.
# [AutoFeat] Final dataframe with 32 feature columns (19 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 2.954921061436263
# 53.875763 * 1/(x007*x012)
# -20.497805 * log(x004)/x007
# 11.961352 * 1/(x002*x007)
# 5.871634 * x005**3/x009
# 4.873419 * sqrt(x011)/x010
# 1.672385 * x005**2/x010
# 0.104367 * x000**2*x003
# -0.055881 * x006/x008
# -0.044846 * x000
# -0.022401 * sqrt(x000)*x012
# 0.001550 * exp(x005)*log(x007)
# 0.000257 * x005**3*sqrt(x011)
# -0.000090 * exp(x005)*log(x000)
# [AutoFeat] Final score: 0.9072
# (506, 32)

# %%
randforreg = RandomForestRegressor(random_state=13)
randforreg.fit(X_af, y)
# define Boruta feature selection method
feat_selector = BorutaPy(randforreg, n_estimators='auto', verbose=2, random_state=11)
# find all relevant features
feat_selector.fit(X_af.iloc[:,:].values, y)
# call transform() on X to filter it down to selected features
XS_af = feat_selector.transform(X_af.iloc[:,:].values)
XS_af.shape
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	32
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	12
# Tentative: 	10
# Rejected: 	10
# Iteration: 	9 / 100
# Confirmed: 	12
# Tentative: 	10
# Rejected: 	10
# Iteration: 	10 / 100
# Confirmed: 	12
# Tentative: 	10
# Rejected: 	10
# Iteration: 	11 / 100
# Confirmed: 	12
# Tentative: 	10
# Rejected: 	10
# Iteration: 	12 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	10
# Iteration: 	13 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	10
# Iteration: 	14 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	10
# Iteration: 	15 / 100
# Confirmed: 	13
# Tentative: 	9
# Rejected: 	10
# Iteration: 	16 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	17 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	18 / 100
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	10
# Iteration: 	19 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	20 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	21 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	22 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	23 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	24 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	25 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	26 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	27 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	28 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	29 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	30 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	31 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	11
# Iteration: 	32 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	33 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	34 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	35 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	36 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	37 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	38 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	39 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	40 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	41 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	42 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	43 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	44 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	45 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	46 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	47 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	48 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	49 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	50 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	11
# Iteration: 	51 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	52 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	53 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	54 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	55 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	56 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	57 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	58 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	59 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	60 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	61 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	62 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	63 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	64 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	65 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	66 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	67 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	68 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	69 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	70 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	71 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	72 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	73 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	74 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	75 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	76 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	77 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	78 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	79 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	80 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	81 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	82 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	83 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	84 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	85 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	86 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	87 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	88 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	89 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	90 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	91 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	92 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	93 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	94 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	95 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	96 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	97 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	98 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# Iteration: 	99 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	19
# Tentative: 	1
# Rejected: 	12
# (506, 19)

# %% [markdown]
# ## Adathalmaz tesztelése

# %%
dsname='boston'

# %%
#Ridge regresszió
print("####", dsname)
warnings.simplefilter("ignore")
rreg = Ridge()
params = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000., 25000., 50000., 100000.]}
rreg = test_model(XS_af, y, rreg, params)
# Out:
# #### boston
# best params: {'alpha': 0.1}
# best score: -10.147572187384004
# MSE on training data: 8.644314970167585
# MSE on test data: 10.214859063861777
# R^2 on training data: 0.8983085574219989
# R^2 on test data: 0.8749868797579294

# %%
#SVR regresszió
print("####", dsname)
svr = SVR(gamma="scale")
params = {"C": [1., 10., 25., 50., 100., 250.]}
svr = test_model(XS_af, y, svr, params)
# Out:
# #### boston
# best params: {'C': 25.0}
# best score: -10.523150971180348
# MSE on training data: 2.6979109004840454
# MSE on test data: 14.09641325076869
# R^2 on training data: 0.9682618631593178
# R^2 on test data: 0.8274830231447128

# %%
#random forest regresszió
print("####", dsname)
rforest = RandomForestRegressor(n_estimators=100, random_state=13)
params = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
rforest = test_model(XS_af, y, rforest, params)
# Out:
# #### boston
# best params: {'min_samples_leaf': 0.0001}
# best score: -10.46805614401234
# MSE on training data: 1.4215822772277231
# MSE on test data: 9.84997339215687
# R^2 on training data: 0.9832765519288101
# R^2 on test data: 0.8794524818838396

# %%
#autofeat regresszió 1 steppel
print("####", dsname)
test_autofeat(XS_af, y, units, feateng_steps=1)
# Out:
# #### boston
# [AutoFeat] The 1 step feature engineering process could generate up to 133 features.
# [AutoFeat] With 404 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 92 transformed features from 19 original features - done.
# [feateng] Generated altogether 94 new features in 1 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 51 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 21 features after 5 feature selection runs
# [featsel] 21 features after correlation filtering
# [featsel] 15 features after noise filtering
# [AutoFeat] Computing 2 new features.
# [AutoFeat]     2/    2 new features ...done.
# [AutoFeat] Final dataframe with 21 feature columns (2 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 5.4962786994834545
# -717.418605 * x008**3
# 101.716355 * x008
# -21.982132 * x009
# 9.053771 * x007
# 1.209086 * x005
# -0.139669 * x000
# -0.105285 * x014
# 0.040726 * 1/x008
# 0.000863 * x013
# 0.000323 * x016
# -0.000115 * x018
# [AutoFeat] Final score: 0.9030
# [AutoFeat] Computing 2 new features.
# [AutoFeat]     2/    2 new features ...done.
# autofeat new features: 2
# autofeat MSE on training data: 8.246976413250394
# autofeat MSE on test data: 10.169642281606563
# autofeat R^2 on training data: 0.9029828353936156
# autofeat R^2 on test data: 0.8755402590068933
# # Ridge Regression
# best params: {'alpha': 0.1}
# best score: -10.001407494962354
# MSE on training data: 8.492907187231602
# MSE on test data: 10.151910841806847
# R^2 on training data: 0.9000897136983994
# R^2 on test data: 0.8757572627464346
# # Random Forest
# best params: {'min_samples_leaf': 0.0001}
# best score: -10.317797589629622
# MSE on training data: 1.4036754331683174
# MSE on test data: 9.90923576470589
# R^2 on training data: 0.9834872074649289
# R^2 on test data: 0.8787272076476526
# # SVR
# best params: {'C': 25.0}
# best score: -12.320385784998294
# MSE on training data: 2.7720861521187294
# MSE on test data: 13.553905860981661
# R^2 on training data: 0.9673892678908265
# R^2 on test data: 0.8341224237598024

# %%
#autofeat regresszió 2 steppel
warnings.simplefilter("ignore")
print("####", dsname)
test_autofeat(XS_af, y, units, feateng_steps=2)
# Out:
# #### boston
# [AutoFeat] The 2 step feature engineering process could generate up to 8911 features.
# [AutoFeat] With 404 data points this new feature matrix would use about 0.01 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 92 transformed features from 19 original features - done.
# [feateng] Step 2: first combination of features
# [feateng] Generated 5979 feature combinations from 6105 original feature tuples - done.
# [feateng] Generated altogether 6138 new features in 2 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 3210 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 71 features after 5 feature selection runs
# [featsel] 51 features after correlation filtering
# [featsel] 24 features after noise filtering
# [AutoFeat] Computing 22 new features.
# [AutoFeat]    22/   22 new features ...done.
# [AutoFeat] Final dataframe with 41 feature columns (22 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 13.653094917184035
# 10681.897852 * x008**2/x013
# -1363.350213 * x009**3*x011
# -372.848140 * x009**3/x014
# 0.813506 * log(x007)*log(x014)
# 0.469008 * sqrt(x008)*sqrt(x016)
# 0.234651 * sqrt(x007)*log(x010)
# 0.126586 * x003*x007**2
# 0.073902 * x007
# -0.062115 * x000**3*x008**3
# -0.054906 * x015*x017
# 0.030722 * sqrt(x013)*x015**2
# -0.001281 * sqrt(x012)/x003
# 0.000214 * sqrt(x006)*exp(x007)
# 0.000014 * x016**2/x013
# -0.000011 * x008**2*x012
# [AutoFeat] Final score: 0.9172
# [AutoFeat] Computing 22 new features.
# [AutoFeat]    22/   22 new features ...done.
# autofeat new features: 22
# autofeat MSE on training data: 7.034677451914062
# autofeat MSE on test data: 11.063449542280495
# autofeat R^2 on training data: 0.9172442812848813
# autofeat R^2 on test data: 0.8646015241840925
# # Ridge Regression
# best params: {'alpha': 250.0}
# best score: -11.348709213035034
# MSE on training data: 6.943009443095619
# MSE on test data: 14.587406271772421
# R^2 on training data: 0.9183226607848384
# R^2 on test data: 0.8214740739082118
# # Random Forest
# best params: {'min_samples_leaf': 0.0001}
# best score: -10.560237016697531
# MSE on training data: 1.3223928044554463
# MSE on test data: 14.298774225490208
# R^2 on training data: 0.9844434136881947
# R^2 on test data: 0.8250064567322928
# # SVR
# best params: {'C': 25.0}
# best score: -11.50179003801779
# MSE on training data: 2.247507417936764
# MSE on test data: 14.649645208648838
# R^2 on training data: 0.9735603952049983
# R^2 on test data: 0.8207123714069021

# %%
#sokáig futna
#autofeat regresszió 3 steppel
#print("####", dsname)
#test_autofeat(XS_af, y, units, feateng_steps=3)
